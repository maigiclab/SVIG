# %%
import pandas as pd

# %%
import musical
import numpy as np
import pickle
import logging
import pandas as pd
import argparse
import sys
import os
sys.path.append('../src/utils/')
from sorted_array import SORTED_CAT_ARRAY
from sorted_array import SORTED_CAT_ARRAY_RT

# %%
#used for the paper
features = 'RFD'
#features = 'repliTiming_mp' # replication timing at midpoint

# %%
matrix_folder = '../data/processed/SVmatrices/PCAWG/'

# %%
breast_fn = matrix_folder+features+'/Breast_'+features+'.csv'
breast_cat = pd.read_csv(breast_fn, index_col=0)

# %%
breast_cat.head(1)
# Out:
#                                       clustered_del_1-10Kb_L_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                         0
#
#                                       clustered_del_1-10Kb_L_R  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                         0
#
#                                       clustered_del_1-10Kb_R_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                         0
#
#                                       clustered_del_1-10Kb_R_R  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                         0
#
#                                       clustered_del_10-100Kb_L_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                           0
#
#                                       clustered_del_10-100Kb_L_R  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                           1
#
#                                       clustered_del_10-100Kb_R_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                           0
#
#                                       clustered_del_10-100Kb_R_R  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                           0
#
#                                       clustered_del_100Kb-1Mb_L_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                            0
#
#                                       clustered_del_100Kb-1Mb_L_R  ...  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                            0  ...
#
#                                       non-clustered_inv_1Mb-10Mb_R_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                               0
#
#                                       non-clustered_inv_1Mb-10Mb_R_R  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                               0
#
#                                       non-clustered_inv_>10Mb_L_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                            0
#
#                                       non-clustered_inv_>10Mb_L_R  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                            1
#
#                                       non-clustered_inv_>10Mb_R_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                            0
#
#                                       non-clustered_inv_>10Mb_R_R  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                            0
#
#                                       non-clustered_trans_L_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                        0
#
#                                       non-clustered_trans_L_R  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                        0
#
#                                       non-clustered_trans_R_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                        0
#
#                                       non-clustered_trans_R_R
# f39cc911-36a7-4c06-9e91-4ad86281db3d                        0
#
# [1 rows x 128 columns]

# %%
ovary_fn = matrix_folder+features+'/Ovary_'+features+'.csv'
ovary_cat = pd.read_csv(ovary_fn, index_col=0)

# %%
prostate_fn = matrix_folder+features+'/Prostate_'+features+'.csv'
prostate_cat = pd.read_csv(prostate_fn, index_col=0)

# %%
esophagus_fn = matrix_folder+features+'/Esophagus_'+features+'.csv'
esophagus_cat = pd.read_csv(esophagus_fn, index_col=0)

# %%
lung_fn = matrix_folder+features+'/Lung_'+features+'.csv'
lung_cat = pd.read_csv(lung_fn, index_col=0)

# %%
sel_pantissue_rfd_cat = pd.concat([breast_cat, ovary_cat, prostate_cat, esophagus_cat, lung_cat]).T

# %%
breast_cat.shape
# Out:
# (187, 128)

# %%
breast_cat.head(1)
# Out:
#                                       clustered_del_1-10Kb_L_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                         0
#
#                                       clustered_del_1-10Kb_L_R  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                         0
#
#                                       clustered_del_1-10Kb_R_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                         0
#
#                                       clustered_del_1-10Kb_R_R  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                         0
#
#                                       clustered_del_10-100Kb_L_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                           0
#
#                                       clustered_del_10-100Kb_L_R  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                           1
#
#                                       clustered_del_10-100Kb_R_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                           0
#
#                                       clustered_del_10-100Kb_R_R  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                           0
#
#                                       clustered_del_100Kb-1Mb_L_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                            0
#
#                                       clustered_del_100Kb-1Mb_L_R  ...  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                            0  ...
#
#                                       non-clustered_inv_1Mb-10Mb_R_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                               0
#
#                                       non-clustered_inv_1Mb-10Mb_R_R  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                               0
#
#                                       non-clustered_inv_>10Mb_L_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                            0
#
#                                       non-clustered_inv_>10Mb_L_R  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                            1
#
#                                       non-clustered_inv_>10Mb_R_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                            0
#
#                                       non-clustered_inv_>10Mb_R_R  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                            0
#
#                                       non-clustered_trans_L_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                        0
#
#                                       non-clustered_trans_L_R  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                        0
#
#                                       non-clustered_trans_R_L  \
# f39cc911-36a7-4c06-9e91-4ad86281db3d                        0
#
#                                       non-clustered_trans_R_R
# f39cc911-36a7-4c06-9e91-4ad86281db3d                        0
#
# [1 rows x 128 columns]

# %%
sel_pantissue_rfd_cat.head(1)
# Out:
#                           f39cc911-36a7-4c06-9e91-4ad86281db3d  \
# clustered_del_1-10Kb_L_L                                     0
#
#                           e7dc7492-3a84-49c7-8dea-8f508b53dc40  \
# clustered_del_1-10Kb_L_L                                     0
#
#                           8f558713-f32b-403b-aedf-c79efeb41c67  \
# clustered_del_1-10Kb_L_L                                     0
#
#                           1eb62abc-7928-405b-84cc-f091ca5347b2  \
# clustered_del_1-10Kb_L_L                                     0
#
#                           f9f04e42-63a2-4ee1-ade4-9e5bb5c20cdd  \
# clustered_del_1-10Kb_L_L                                     1
#
#                           ec4d4cbc-d5d1-418d-a292-cad9576624fd  \
# clustered_del_1-10Kb_L_L                                     2
#
#                           01658141-8398-4585-9f0f-8355dd9b0604  \
# clustered_del_1-10Kb_L_L                                     0
#
#                           fc6d77a9-121b-48ab-a899-713c3d1319a2  \
# clustered_del_1-10Kb_L_L                                     0
#
#                           07b5141f-ac79-439b-883b-b0183bbe7ff5  \
# clustered_del_1-10Kb_L_L                                     0
#
#                           7b0b60c7-5fa0-440e-937f-8d82119330d6  ...  \
# clustered_del_1-10Kb_L_L                                     0  ...
#
#                           706868b5-4920-433a-bea3-92e9bf83059b  \
# clustered_del_1-10Kb_L_L                                     1
#
#                           b7a7d93b-38a7-4fc3-a433-3bb0a8cb7c42  \
# clustered_del_1-10Kb_L_L                                     0
#
#                           2fe2433b-9a55-431f-a869-2b5a63e8e8fc  \
# clustered_del_1-10Kb_L_L                                     0
#
#                           84e601b7-dfa5-4cd5-9fef-07f03967a0d4  \
# clustered_del_1-10Kb_L_L                                     0
#
#                           9623d295-c23d-4f2f-827c-69f767a26f1f  \
# clustered_del_1-10Kb_L_L                                     0
#
#                           b88f014e-bc0f-4775-8228-39e0b471c3b0  \
# clustered_del_1-10Kb_L_L                                     0
#
#                           24badf07-8615-48a3-8d6e-45c3d783f18d  \
# clustered_del_1-10Kb_L_L                                     0
#
#                           7ac0b303-d685-4fa5-bfec-34d2ba1dbc8e  \
# clustered_del_1-10Kb_L_L                                     0
#
#                           ad41f1f3-e38e-4418-9c16-52bca5719f39  \
# clustered_del_1-10Kb_L_L                                     0
#
#                           48f68f73-3ac0-44ac-ba12-b8889fcb7f38
# clustered_del_1-10Kb_L_L                                     0
#
# [1 rows x 631 columns]

# %%
sel_pantissue_rfd_cat.index.name = 'Mutation type'
sel_pantissue_rfd_cat.to_csv(matrix_folder+features+'/Selected_'+features+'.csv')
